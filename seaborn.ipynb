# %% [markdown]
# ## Using Seaborn to Visualize data

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Loading the dataset 
dataset = pd.read_csv("euro-daily-hist_1999_2022.csv")
dataset.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2023-12-15               1.6324           1.9558            5.4085
# 1   2023-12-14               1.6288           1.9558            5.3349
# 2   2023-12-13               1.6452           1.9558            5.3609
# 3   2023-12-12               1.6398           1.9558            5.3327
# 4   2023-12-11                1.642           1.9558            5.3169
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.4653         0.9488                   7.7812              NaN
# 1             1.4677          0.949                   7.7866              NaN
# 2             1.4644         0.9452                   7.7426              NaN
# 3             1.4656         0.9443                   7.7447              NaN
# 4             1.4609         0.9478                   7.7206              NaN
#
# ...

# %%
extract = dataset.iloc[:, [0, 1, 4, -2]]
extract.head()
# Out:
#   Period\Unit: [Australian dollar ] [Canadian dollar ] [US dollar ]
# 0   2023-12-15               1.6324             1.4653       1.0946
# 1   2023-12-14               1.6288             1.4677       1.0919
# 2   2023-12-13               1.6452             1.4644       1.0787
# 3   2023-12-12               1.6398             1.4656       1.0804
# 4   2023-12-11                1.642             1.4609       1.0757

# %%
# Renaming the columns 
extract.columns = ["Date", "Australian Dollar", "Canadian Dollar", "US Dollar"]
extract.head()
# Out:
#          Date Australian Dollar Canadian Dollar US Dollar
# 0  2023-12-15            1.6324          1.4653    1.0946
# 1  2023-12-14            1.6288          1.4677    1.0919
# 2  2023-12-13            1.6452          1.4644    1.0787
# 3  2023-12-12            1.6398          1.4656    1.0804
# 4  2023-12-11             1.642          1.4609    1.0757

# %%
sns.lineplot(x=extract.Date, y=extract["US Dollar"], data=extract)
# Out:
# <Axes: xlabel='Date', ylabel='US Dollar'>

# %%
sns.barplot(x=list("abcdefgh"), y=np.random.randint(10, 100, 8))
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'a'),
#   Text(1, 0, 'b'),
#   Text(2, 0, 'c'),
#   Text(3, 0, 'd'),
#   Text(4, 0, 'e'),
#   Text(5, 0, 'f'),
#   Text(6, 0, 'g'),
#   Text(7, 0, 'h')])
